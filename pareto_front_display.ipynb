# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

file_path = '/content/drive/MyDrive/giicis/result_nrp_100c_140r.dat_1670286696.json'
df = pd.read_json(file_path)
df
# Out:
#      iteration  profit  cost              x             y      time      pid
# 0            0     756   189  1.100010e+138  1.111010e+97  0.232134  3737455
# 1            1     743   186  1.100010e+138  1.111010e+97  0.444185  3737455
# 2            2     735   182  1.100010e+138  1.111010e+97  0.296965  3737455
# 3            3     723   181  1.100010e+138  1.111010e+97  0.551822  3737455
# 4            4     720   179  1.100010e+138  1.111010e+97  0.768326  3737455
# ..         ...     ...   ...            ...           ...       ...      ...
# 391         46    1840   576  1.110101e+139  1.111101e+98  0.354747  3737458
# 392         47    1828   575  1.110101e+139  1.111101e+98  0.667013  3737458
# 393         48    1821   574  1.110101e+139  1.111101e+98  1.076593  3737458
# 394         49    1821   572  1.110101e+139  1.111111e+99  0.979490  3737458
# 395         50    1816   570  1.110101e+139  1.111101e+98  1.091290  3737458
#
# [396 rows x 7 columns]

# %%
df['pid'] = df['pid'].astype('str')
sns.scatterplot(data=df, x='profit', y='cost')

# %%
file_path = '/content/drive/MyDrive/giicis/result_nrp_750c_3250r.dat_1670021954.json'
df = pd.read_json(file_path)
df['pid'] = df['pid'].astype('str')
sns.scatterplot(data=df, x='profit', y='cost')
# 10:53 horas

# %%
file_path = '/content/drive/MyDrive/giicis/result_nrp_1000c_1500r.dat_1670175110.json'
df = pd.read_json(file_path)
df['pid'] = df['pid'].astype('str')
sns.scatterplot(data=df, x='profit', y='cost')
# 11 min

# %%
file_path = '/content/drive/MyDrive/giicis/result_nrp_536c_3502r.dat_1669954912.json'
df = pd.read_json(file_path)
df['pid'] = df['pid'].astype('str')
sns.scatterplot(data=df, x='profit', y='cost')
