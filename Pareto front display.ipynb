# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px

epsilon = 0.001
file_path = '/content/drive/MyDrive/giicis/result.json'
df = pd.read_json(file_path)
df
# Out:
#      iteration  profit  cost              x             y
# 0            0    2885   761  1.110111e+139  1.111111e+99
# 1            1    2865   743  1.110111e+139  1.111111e+99
# 2            2    2844   725  1.110111e+139  1.111111e+99
# 3            3    2825   714  1.110111e+139  1.111111e+99
# 4            4    2804   704  1.110111e+139  1.111111e+99
# ..         ...     ...   ...            ...           ...
# 388        388      59     7  1.000000e+125  1.000010e+62
# 389        389      50     4  1.000000e+138  1.000000e+62
# 390        390      27     3  1.000000e+138  1.000000e+22
# 391        391      23     1  1.000000e+125  1.000000e+62
# 392        392       0     0   0.000000e+00  0.000000e+00
#
# [393 rows x 5 columns]

# %%
sns.scatterplot(data=df, x='profit', y='cost').set(title=f'Pareto front NRP epsilon={epsilon}')
# Out:
# [Text(0.5, 1.0, 'Pareto front NRP epsilon=0.001')]

# %%
fig = px.scatter(df, x='profit', y='cost', title=f'Pareto front NRP epsilon={epsilon}')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
